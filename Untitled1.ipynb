# %%
import requests 


url = 'https://mesonet.agron.iastate.edu/cgi-bin/request/asos.py?station=MLB&data=tmpc&data=dwpc&data=relh&data=drct&data=sped&year1=2024&month1=12&day1=1&year2=2024&month2=12&day2=31&tz=Etc%2FUTC&format=onlycomma&latlon=yes&elev=yes&missing=M&trace=T&direct=no&report_type=1'

r = requests.get(url, allow_redirects=True)

open('asos_5min_KMLB.dat','wb').write(r.content)
# Out:
# 517817

# %%
import pandas as pd 


dft = pd.read_csv('asos_5min_KMLB.dat')
# Out:
#      station             valid      lon      lat  elevation tmpc dwpc relh  \
# 0        MLB  2024-12-01 00:00 -80.6453  28.1028       11.0    M    M    M
# 1        MLB  2024-12-01 00:05 -80.6453  28.1028       11.0    M    M    M
# 2        MLB  2024-12-01 00:10 -80.6453  28.1028       11.0    M    M    M
# 3        MLB  2024-12-01 00:15 -80.6453  28.1028       11.0    M    M    M
# 4        MLB  2024-12-01 00:20 -80.6453  28.1028       11.0    M    M    M
# ...      ...               ...      ...      ...        ...  ...  ...  ...
# 8433     MLB  2024-12-30 23:35 -80.6453  28.1028       11.0    M    M    M
# 8434     MLB  2024-12-30 23:40 -80.6453  28.1028       11.0    M    M    M
# 8435     MLB  2024-12-30 23:45 -80.6453  28.1028       11.0    M    M    M
# 8436     MLB  2024-12-30 23:50 -80.6453  28.1028       11.0    M    M    M
# 8437     MLB  2024-12-30 23:55 -80.6453  28.1028       11.0    M    M    M
#
#         drct   sped
# 0     340.00  11.50
# 1     340.00  11.50
# ...

# %%
import xarray as xr 

dset = xr.open_dataset('netcd_mlb_dec/data_stream-oper_stepType-instant.nc')

dset
# Out:
# <xarray.Dataset> Size: 86MB
# Dimensions:     (valid_time: 744, latitude: 9, longitude: 645)
# Coordinates:
#     number      int64 8B ...
#   * valid_time  (valid_time) datetime64[ns] 6kB 2024-12-01 ... 2024-12-31T23:...
#   * latitude    (latitude) float64 72B 29.0 28.75 28.5 28.25 ... 27.5 27.25 27.0
#   * longitude   (longitude) float64 5kB -81.0 -80.75 -80.5 ... 79.5 79.75 80.0
#     expver      (valid_time) <U4 12kB ...
# Data variables:
#     u10         (valid_time, latitude, longitude) float32 17MB ...
#     v10         (valid_time, latitude, longitude) float32 17MB ...
#     d2m         (valid_time, latitude, longitude) float32 17MB ...
#     t2m         (valid_time, latitude, longitude) float32 17MB ...
#     sp          (valid_time, latitude, longitude) float32 17MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
# ...

# %%
dset_mlb = dset.sel(longitude=-80.64,latitude=
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 print(fetch_metar.data)
#
# AttributeError: 'function' object has no attribute 'data'
